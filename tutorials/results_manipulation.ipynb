# %% [markdown]
# ## Results manipulation with remayn
#
# ### 1. Running some experiments with GridSearchCV and saving the results
#
# A Logistic Regression model and a Ridge Classifier are trained using a GridSearch cross-validation procedure. Then, the results are saved including the best parameters found.

# %%
from remayn.result import make_result
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
import time
from shutil import rmtree
from remayn.result_set import ResultFolder

# %%
# Clean up the results folder if exists
rmtree('./results')

# Repeat the experiment 10 times with different random seeds
for seed in range(10):
    for model, param_grid in [(LogisticRegression, {'C': [0.1, 1, 10], 'max_iter': [50, 100, 150]}),
                              (RidgeClassifier, {'alpha': [0.1, 1, 10], 'max_iter': [50, 100, 150]})]:
        # Generate a sample dataset
        X, y = make_classification(n_samples=1000, n_features=20, n_informative=2, n_redundant=2, n_clusters_per_class=2, random_state=0)

        # Split the dataset into training and test sets
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

        # Train the model
        start_time = time.time()

        gs = GridSearchCV(model(), param_grid=param_grid, cv=5)
        gs.fit(X_train, y_train)

        train_time = time.time() - start_time

        # Make predictions
        y_train_pred = gs.predict(X_train)
        y_test_pred = gs.predict(X_test)

        # Prepare estimator config that is going to be saved
        estimator_config = gs.get_params()
        # Remove the 'estimator' key from the config, as it is not serializable
        estimator_config.pop('estimator')

        # Create a dictionary that represents the config of this experiment.
        # Any information relevant for the experiment can be included here.
        # In this case, all the hyperparameters of the estimator are included.
        experiment_config = {
            "estimator_config": estimator_config,
            "estimator_name": model.__name__,
            "seed": seed,
        }

        # Save the results of the experiment
        make_result(
            base_path='./results',
            config=experiment_config,
            targets=y_test,
            predictions=y_test_pred,
            train_targets=y_train,
            train_predictions=y_train_pred,
            time=train_time,

            # Save the best hyperparameters and the best model
            best_params=gs.best_params_,
            best_model=gs.best_estimator_
        ).save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-78071a6911c6> in <cell line: 2>()
#       1 # Clean up the results folder if exists
# ----> 2 rmtree('./results')
#       3
#       4 # Repeat the experiment 10 times with different random seeds
#       5 for seed in range(10):
#
# ~/anaconda3/envs/remayndev/lib/python3.8/shutil.py in rmtree(path, ignore_errors, onerror)
#     707             orig_st = os.lstat(path)
#     708         except Exception:
# --> 709             onerror(os.lstat, path, sys.exc_info())
#     710             return
#     711         try:
#
# ~/anaconda3/envs/remayndev/lib/python3.8/shutil.py in rmtree(path, ignore_errors, onerror)
#     705         # lstat()/open()/fstat() trick.
#     706         try:
# --> 707             orig_st = os.lstat(path)
#     708         except Exception:
#     709             onerror(os.lstat, path, sys.exc_info())
#
# FileNotFoundError: [Errno 2] No such file or directory: './results'

# %% [markdown]
# ### 2. Loading the results folder and visualizing the results

# %%
# Load the results from the folder
rf = ResultFolder('./results')
print(rf)

# Iterate over the results and print them
for result in rf:
    print(result)
# Out:
# ResultSet with 20 results
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 9
# }
# Results info path: results/11744a9e-3f9c-429c-b6d7-ca00cc051e35.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 3
# }
# Results info path: results/4bef67fa-290e-469f-af81-98c3dabf4f79.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 6
# }
# Results info path: results/740a9e2a-f42b-47f6-bca0-bf33950047c7.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 1
# }
# Results info path: results/00206c56-0130-4815-8d4d-e2e06369fd92.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 9
# }
# Results info path: results/427fdae5-52c1-4b7a-bf15-03a0684f5e92.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 2
# }
# Results info path: results/2e12414f-39d0-4c98-a84e-a88c343fb467.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 4
# }
# Results info path: results/eb827713-5cf6-49cd-8257-5a5ee7e7953e.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 6
# }
# Results info path: results/99127c6b-0392-4ef5-9d43-5b4c3b741ac0.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 7
# }
# Results info path: results/e37d0107-1006-4f50-bd87-0a154e4b9720.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 2
# }
# Results info path: results/f75d137a-a8de-4832-a438-c159d10e10f3.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 7
# }
# Results info path: results/3ae9819b-7e05-4591-a100-a5b0dce0f446.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 1
# }
# Results info path: results/512700ce-7dd8-4125-93ac-22c2d421aa5d.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 3
# }
# Results info path: results/322aaead-77e1-474f-827b-b85b5844d1eb.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 8
# }
# Results info path: results/37eda2d8-b78d-41f1-86e0-c8683adb3204.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 5
# }
# Results info path: results/616698a3-6e8f-4025-ba63-3b7dd49c1819.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 5
# }
# Results info path: results/96ea91a6-c70e-46b6-85df-6091f2fd7df4.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 0
# }
# Results info path: results/22d0fac6-9a97-4eb0-b9e2-b0dfca87e7e4.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 0
# }
# Results info path: results/11dfb8bf-916f-4f63-954f-2381b946bb9e.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 8
# }
# Results info path: results/0e22941f-edff-4374-8ecf-9cdbff80721c.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 4
# }
# Results info path: results/b35968f4-a27e-41b5-9d1a-4318e26fcb3e.json (data not loaded)

# %% [markdown]
# ### 3. Deleting a specific experiment
#
# If we want to remove a specific experiments, for example, to repeat it, we can find it and remove it using remayn functions. The directory where the results are stored should not be manipulated manually.

# %%
def filter_fn(result):
    return result.config['estimator_name'] == 'LogisticRegression' and result.config['seed'] == 0

# Filter the results
filtered_results = rf.filter(filter_fn)
print(filtered_results)

for result in filtered_results:
    print(f"Deleting the result {result}")
    # Delete the result from disk
    result.delete()
# Out:
# ResultSet with 1 result
# Deleting the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__C": 1.0,
#         "estimator__class_weight": null,
#         "estimator__dual": false,
#         "estimator__fit_intercept": true,
#         "estimator__intercept_scaling": 1,
#         "estimator__l1_ratio": null,
#         "estimator__max_iter": 100,
#         "estimator__multi_class": "auto",
#         "estimator__n_jobs": null,
#         "estimator__penalty": "l2",
#         "estimator__random_state": null,
#         "estimator__solver": "lbfgs",
#         "estimator__tol": 0.0001,
#         "estimator__verbose": 0,
#         "estimator__warm_start": false,
#         "n_jobs": null,
#         "param_grid": {
#             "C": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "LogisticRegression",
#     "seed": 0
# }
# Results info path: results/22d0fac6-9a97-4eb0-b9e2-b0dfca87e7e4.json (data not loaded)

# %% [markdown]
# Now we can load the result folder again and check that the result has been removed

# %%
rf = ResultFolder('./results')
print(rf)

# Filtered results should be empty now
filtered_results = rf.filter(filter_fn)
print(filtered_results)
# Out:
# ResultSet with 19 results
# ResultSet with 0 result

# %% [markdown]
# ### 4. Copying some experiments to a different path
#
# In this example, we will move all the experiments from the RidgeClassifier to a new directory named `results_ridge`

# %%
def filter_fn(result):
    return result.config['estimator_name'] == 'RidgeClassifier'

# Remove the results in the new directory if any exists
rmtree('./results_ridge')

for result in rf.filter(filter_fn):
    print(f'Moving the result {result}')

    # Move the result to a different folder
    new_result = result.copy_to('./results_ridge')

    # The new result will show the new path
    print(new_result)
# Out:
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 9
# }
# Results info path: results/11744a9e-3f9c-429c-b6d7-ca00cc051e35.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 9
# }
# Results info path: results_ridge/11744a9e-3f9c-429c-b6d7-ca00cc051e35.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 2
# }
# Results info path: results/2e12414f-39d0-4c98-a84e-a88c343fb467.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 2
# }
# Results info path: results_ridge/2e12414f-39d0-4c98-a84e-a88c343fb467.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 4
# }
# Results info path: results/eb827713-5cf6-49cd-8257-5a5ee7e7953e.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 4
# }
# Results info path: results_ridge/eb827713-5cf6-49cd-8257-5a5ee7e7953e.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 6
# }
# Results info path: results/99127c6b-0392-4ef5-9d43-5b4c3b741ac0.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 6
# }
# Results info path: results_ridge/99127c6b-0392-4ef5-9d43-5b4c3b741ac0.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 7
# }
# Results info path: results/e37d0107-1006-4f50-bd87-0a154e4b9720.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 7
# }
# Results info path: results_ridge/e37d0107-1006-4f50-bd87-0a154e4b9720.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 1
# }
# Results info path: results/512700ce-7dd8-4125-93ac-22c2d421aa5d.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 1
# }
# Results info path: results_ridge/512700ce-7dd8-4125-93ac-22c2d421aa5d.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 3
# }
# Results info path: results/322aaead-77e1-474f-827b-b85b5844d1eb.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 3
# }
# Results info path: results_ridge/322aaead-77e1-474f-827b-b85b5844d1eb.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 5
# }
# Results info path: results/96ea91a6-c70e-46b6-85df-6091f2fd7df4.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 5
# }
# Results info path: results_ridge/96ea91a6-c70e-46b6-85df-6091f2fd7df4.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 0
# }
# Results info path: results/11dfb8bf-916f-4f63-954f-2381b946bb9e.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 0
# }
# Results info path: results_ridge/11dfb8bf-916f-4f63-954f-2381b946bb9e.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 8
# }
# Results info path: results/0e22941f-edff-4374-8ecf-9cdbff80721c.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 8
# }
# Results info path: results_ridge/0e22941f-edff-4374-8ecf-9cdbff80721c.json (data not loaded)

# %% [markdown]
# Now we can load the results in the new directory:

# %%
rf_ridge = ResultFolder('./results_ridge')
print(rf_ridge)
# Out:
# ResultSet with 10 results

# %% [markdown]
# ### 5. Moving the results to a new location
#
# Moving the results consist of copying them and then removing them from the original location. We will repeat the previous example, but, in this case, we will move the results instead of copying them.

# %%
def filter_fn(result):
    return result.config['estimator_name'] == 'RidgeClassifier'

# Remove the results in the new directory if any exists
rmtree('./results_ridge')

for result in rf.filter(filter_fn):
    print(f'Moving the result {result}')

    # Move the result to a different folder
    new_result = result.copy_to('./results_ridge')
    result.delete()

    # The new result will show the new path
    print(new_result)
# Out:
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 9
# }
# Results info path: results/11744a9e-3f9c-429c-b6d7-ca00cc051e35.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 9
# }
# Results info path: results_ridge/11744a9e-3f9c-429c-b6d7-ca00cc051e35.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 2
# }
# Results info path: results/2e12414f-39d0-4c98-a84e-a88c343fb467.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 2
# }
# Results info path: results_ridge/2e12414f-39d0-4c98-a84e-a88c343fb467.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 4
# }
# Results info path: results/eb827713-5cf6-49cd-8257-5a5ee7e7953e.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 4
# }
# Results info path: results_ridge/eb827713-5cf6-49cd-8257-5a5ee7e7953e.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 6
# }
# Results info path: results/99127c6b-0392-4ef5-9d43-5b4c3b741ac0.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 6
# }
# Results info path: results_ridge/99127c6b-0392-4ef5-9d43-5b4c3b741ac0.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 7
# }
# Results info path: results/e37d0107-1006-4f50-bd87-0a154e4b9720.json (data not loaded)
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 7
# }
# Results info path: results_ridge/e37d0107-1006-4f50-bd87-0a154e4b9720.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 1
# }
# Results info path: results/512700ce-7dd8-4125-93ac-22c2d421aa5d.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 1
# }
# Results info path: results_ridge/512700ce-7dd8-4125-93ac-22c2d421aa5d.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 3
# }
# Results info path: results/322aaead-77e1-474f-827b-b85b5844d1eb.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 3
# }
# Results info path: results_ridge/322aaead-77e1-474f-827b-b85b5844d1eb.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 5
# }
# Results info path: results/96ea91a6-c70e-46b6-85df-6091f2fd7df4.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 5
# }
# Results info path: results_ridge/96ea91a6-c70e-46b6-85df-6091f2fd7df4.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 0
# }
# Results info path: results/11dfb8bf-916f-4f63-954f-2381b946bb9e.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 0
# }
# Results info path: results_ridge/11dfb8bf-916f-4f63-954f-2381b946bb9e.json (data not loaded)
#
# Moving the result Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 8
# }
# Results info path: results/0e22941f-edff-4374-8ecf-9cdbff80721c.json (data not loaded)
#
# Config: {
#     "estimator_config": {
#         "cv": 5,
#         "error_score": NaN,
#         "estimator__alpha": 1.0,
#         "estimator__class_weight": null,
#         "estimator__copy_X": true,
#         "estimator__fit_intercept": true,
#         "estimator__max_iter": null,
#         "estimator__positive": false,
#         "estimator__random_state": null,
#         "estimator__solver": "auto",
#         "estimator__tol": 0.0001,
#         "n_jobs": null,
#         "param_grid": {
#             "alpha": [
#                 0.1,
#                 1,
#                 10
#             ],
#             "max_iter": [
#                 50,
#                 100,
#                 150
#             ]
#         },
#         "pre_dispatch": "2*n_jobs",
#         "refit": true,
#         "return_train_score": false,
#         "scoring": null,
#         "verbose": 0
#     },
#     "estimator_name": "RidgeClassifier",
#     "seed": 8
# }
# Results info path: results_ridge/0e22941f-edff-4374-8ecf-9cdbff80721c.json (data not loaded)

# %% [markdown]
# To check that the results have been succesfully moved, we will create a dataframe for each directory. In this way, we can verify that the first will only have results from the LogisticRegression and the second will only have results from RidgeClassifier.

# %%
# Define a simple metrics function
def compute_metrics(targets, predictions):
    return {
        'accuracy': (targets == predictions).mean()
    }

# Create the first dataframe
# Note that we have to reload the result folder because it may still include moved/deleted results
rf = ResultFolder('./results')
df1 = rf.create_dataframe(
    config_columns=['estimator_name', 'seed'],
    metrics_fn=compute_metrics,
)

df1
# Out:
#   config_estimator_name  config_seed  accuracy      time
# 0    LogisticRegression            3     0.970  0.466302
# 1    LogisticRegression            6     0.950  0.492846
# 2    LogisticRegression            1     0.945  0.417536
# 3    LogisticRegression            9     0.930  0.514410
# 4    LogisticRegression            2     0.950  0.421934
# 5    LogisticRegression            7     0.930  0.419323
# 6    LogisticRegression            8     0.925  0.426479
# 7    LogisticRegression            5     0.945  0.428291
# 8    LogisticRegression            4     0.930  0.422425

# %%
# Create the second dataframe
rf_ridge = ResultFolder('./results_ridge')
df2 = rf_ridge.create_dataframe(
    config_columns=['estimator_name'],
    metrics_fn=compute_metrics,
)

df2
# Out:
#   config_estimator_name  accuracy      time
# 0       RidgeClassifier     0.920  0.284044
# 1       RidgeClassifier     0.945  0.360493
# 2       RidgeClassifier     0.925  0.285255
# 3       RidgeClassifier     0.950  0.284801
# 4       RidgeClassifier     0.925  0.285887
# 5       RidgeClassifier     0.935  0.284398
# 6       RidgeClassifier     0.965  0.289997
# 7       RidgeClassifier     0.940  0.284951
# 8       RidgeClassifier     0.920  0.284594
# 9       RidgeClassifier     0.960  0.284985

# %% [markdown]
# ### 6. Removing a experiment from the result set (or result folder)
#
# We can also remove a experiment from the collection without physically removing it from the disk. It can be done with `.remove()` method of the `ResultSet`.

# %%
# Load the results
rf = ResultFolder('./results')
print(f"Initial ResultSet: {rf}")

# For simplicity, get the first result
first_result = list(rf)[0]

# Remove it from the ResultFolder
rf.remove(first_result)

print(f"ResultSet after removing {rf}")

# Check that if we load the result folder again, the removed result is still present
rf = ResultFolder('./results')
print(f"ResultSet after reloading {rf}")

# We can also remove it by config
rf.remove(first_result.config)

print(f"ResultSet after removing by config: {rf}")
# Out:
# Initial ResultSet: ResultSet with 9 results
# ResultSet after removing ResultSet with 8 results
# ResultSet after reloading ResultSet with 9 results
# ResultSet after removing by config: ResultSet with 8 results
